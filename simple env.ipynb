# %%
import gymnasium as gym 
import pygame
from gymnasium import Env
from gymnasium.spaces import Discrete, Box, Dict, Tuple, MultiBinary, MultiDiscrete 
import numpy as np
import random, time
import os
from stable_baselines3 import PPO, DQN
from stable_baselines3.common.env_checker import check_env
from stable_baselines3.common.vec_env import VecFrameStack
from stable_baselines3.common.evaluation import evaluate_policy
print('done')
# Out:
# done

# %%
class MowerEnv(Env):
    def __init__(self, len, render_mode = True):
        self.len = len
        self.render_mode = render_mode
        if render_mode == True:
            pygame.init()
            self.screen = pygame.display.set_mode((720, 720))      
        # Actions we can forward, turnleft, turnright
        self.action_space = Discrete(4)
        # 0=visited, 1=notvisited, 2=wall, 3=car (non one hot encoded)
        self.observation_space = Box(0, 4, shape=(self.len, self.len))
        # Set starting state
        self.state = np.ones((self.len, self.len), dtype=np.float32)
        self.state[0][0] = 3
        self.pos = [0, 0]
        # Set length
        self.running_length = (self.len+4)*(self.len+4)
        self.direct = [[-1, 0], [0, 1], [1, 0], [0, -1]]
        
    def step(self, action):
        reward = 0
        # Apply action (no walls for now)
        x = self.pos[0] + self.direct[action][0]
        y = self.pos[1] + self.direct[action][1]
        if x < 0 or x >= self.len or y < 0 or y >= self.len:
            reward = -5.0
        else:
            if self.state[x][y] == 1:
                reward = 1.0
            elif self.state[x][y] == 0:
                reward = -1.0
            self.state[x][y] = 3
            self.state[self.pos[0]][self.pos[1]] = 0
            self.pos = [x, y]
        
        # Reduce shower length by 1 second
        self.running_length -= 1 
        
        # Check if shower is done
        if self.running_length <= 0: 
            done = True
        else:
            done = False
        if np.sum(self.state) == 3:
            reward = self.len * self.len * 3
            done = True
        # Apply temperature noise
        #self.state += random.randint(-1,1)
        # Set placeholder for info
        info = {}
        
        # Return step information
        return (self.state, reward, done, False, info)

    def render(self):
        # Implement viz
        if self.render_mode == True:
            pygame.event.get()
            gap = 720//self.len
            for i in range(0, 720, gap):
                for j in range(0, 720, gap):
                    if self.state[i//gap][j//gap] == 0:
                        color = (255, 255, 255)
                    elif self.state[i//gap][j//gap] == 1:
                        color = (255, 255,0)
                    elif self.state[i//gap][j//gap] == 3:
                        color = (255, 0, 0)
                    pygame.draw.rect(self.screen, color, (j, i, gap, gap))
            pygame.display.update()
    
    
    def reset(self, seed=None, options=None):
        # Set starting state
        self.state = np.ones((self.len, self.len), dtype=np.float32)
        self.state[0][0] = 0
        self.state[0][0] = 3
        self.pos = [0, 0]
        # Set length
        self.running_length = (self.len+4)*(self.len+4)
        return self.state, {}
    
    def close(self):
        pass

# %%
# Out:
# array([[2, 3, 0, 1, 0, 3, 0, 0],
#        [1, 3, 5, 0, 5, 2, 3, 5],
#        [5, 1, 1, 1, 2, 4, 2, 2],
#        [1, 4, 1, 1, 3, 4, 2, 1],
#        [0, 3, 5, 4, 5, 4, 5, 0],
#        [4, 1, 4, 5, 0, 3, 0, 1],
#        [3, 5, 3, 3, 4, 3, 0, 3],
#        [0, 5, 2, 3, 0, 1, 4, 5]], dtype=int64)

# %%
env = MowerEnv(36, True)

# %%
check_env(env)

# %%
#model = DQN("MlpPolicy", env, verbose=1)
model = PPO("MlpPolicy", env, verbose=1, gamma=0.999)
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
model.learn(total_timesteps=400000)
# Out:
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.6e+03  |
# |    ep_rew_mean     | -976     |
# | time/              |          |
# |    fps             | 466      |
# |    iterations      | 1        |
# |    time_elapsed    | 4        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.6e+03     |
# |    ep_rew_mean          | -1.39e+03   |
# | time/                   |             |
# |    fps                  | 356         |
# |    iterations           | 2           |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.017953143 |
# |    clip_fraction        | 0.211       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | -0.0106     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 17.9        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0251     |
# |    value_loss           | 81.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.6e+03     |
# |    ep_rew_mean          | -1.47e+03   |
# | time/                   |             |
# |    fps                  | 328         |
# |    iterations           | 3           |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.017240796 |
# |    clip_fraction        | 0.16        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | 0.00805     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 295         |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0133     |
# |    value_loss           | 744         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.6e+03     |
# |    ep_rew_mean          | -1.3e+03    |
# | time/                   |             |
# |    fps                  | 319         |
# |    iterations           | 4           |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.013615089 |
# |    clip_fraction        | 0.0977      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | 2.65e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 34.3        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.016      |
# |    value_loss           | 137         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.6e+03     |
# |    ep_rew_mean          | -1.42e+03   |
# | time/                   |             |
# |    fps                  | 313         |
# |    iterations           | 5           |
# |    time_elapsed         | 32          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.014467459 |
# |    clip_fraction        | 0.182       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | 1.85e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 84.3        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0171     |
# |    value_loss           | 261         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.6e+03     |
# |    ep_rew_mean          | -1.38e+03   |
# | time/                   |             |
# |    fps                  | 304         |
# |    iterations           | 6           |
# |    time_elapsed         | 40          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.020120382 |
# |    clip_fraction        | 0.305       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | -7.87e-06   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 347         |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0206     |
# |    value_loss           | 728         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.6e+03     |
# |    ep_rew_mean          | -1.29e+03   |
# | time/                   |             |
# |    fps                  | 302         |
# |    iterations           | 7           |
# |    time_elapsed         | 47          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.011244686 |
# |    clip_fraction        | 0.121       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | -6.44e-06   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 45.5        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00627    |
# |    value_loss           | 101         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.6e+03     |
# |    ep_rew_mean          | -1.27e+03   |
# | time/                   |             |
# |    fps                  | 303         |
# |    iterations           | 8           |
# |    time_elapsed         | 53          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.014719446 |
# |    clip_fraction        | 0.176       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | 6.68e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 83.5        |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0139     |
# |    value_loss           | 172         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.6e+03     |
# |    ep_rew_mean          | -1.31e+03   |
# | time/                   |             |
# |    fps                  | 301         |
# |    iterations           | 9           |
# |    time_elapsed         | 61          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.014484307 |
# |    clip_fraction        | 0.211       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | 2.92e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 134         |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0122     |
# |    value_loss           | 333         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.6e+03     |
# |    ep_rew_mean          | -1.35e+03   |
# | time/                   |             |
# |    fps                  | 300         |
# |    iterations           | 10          |
# |    time_elapsed         | 68          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.016354326 |
# |    clip_fraction        | 0.182       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | -4.77e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 184         |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0146     |
# |    value_loss           | 506         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.6e+03     |
# |    ep_rew_mean          | -1.3e+03    |
# | time/                   |             |
# |    fps                  | 298         |
# |    iterations           | 11          |
# |    time_elapsed         | 75          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.014404153 |
# |    clip_fraction        | 0.201       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | -5.96e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 145         |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0167     |
# |    value_loss           | 382         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.6e+03     |
# |    ep_rew_mean          | -1.28e+03   |
# | time/                   |             |
# |    fps                  | 298         |
# |    iterations           | 12          |
# |    time_elapsed         | 82          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.017664105 |
# |    clip_fraction        | 0.2         |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 71.2        |
# |    n_updates            | 110         |
# |    policy_gradient_loss | 0.00227     |
# |    value_loss           | 196         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.6e+03     |
# |    ep_rew_mean          | -1.25e+03   |
# | time/                   |             |
# |    fps                  | 298         |
# |    iterations           | 13          |
# |    time_elapsed         | 89          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.012354674 |
# |    clip_fraction        | 0.115       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | 6.56e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 40.4        |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00772    |
# |    value_loss           | 164         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.6e+03     |
# |    ep_rew_mean          | -1.25e+03   |
# | time/                   |             |
# |    fps                  | 299         |
# |    iterations           | 14          |
# |    time_elapsed         | 95          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.014289613 |
# |    clip_fraction        | 0.0894      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | -9.18e-06   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 126         |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00881    |
# |    value_loss           | 144         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.6e+03     |
# |    ep_rew_mean          | -1.22e+03   |
# | time/                   |             |
# |    fps                  | 299         |
# |    iterations           | 15          |
# |    time_elapsed         | 102         |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.012521826 |
# |    clip_fraction        | 0.0423      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | -3.58e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 59.2        |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00767    |
# |    value_loss           | 230         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.6e+03     |
# |    ep_rew_mean          | -1.22e+03   |
# | time/                   |             |
# |    fps                  | 299         |
# |    iterations           | 16          |
# |    time_elapsed         | 109         |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.013461564 |
# |    clip_fraction        | 0.0975      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 105         |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0131     |
# |    value_loss           | 300         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.6e+03     |
# |    ep_rew_mean          | -1.21e+03   |
# | time/                   |             |
# |    fps                  | 299         |
# |    iterations           | 17          |
# |    time_elapsed         | 116         |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.018452443 |
# |    clip_fraction        | 0.113       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | 2.15e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 57.9        |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.00602    |
# |    value_loss           | 174         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.6e+03     |
# |    ep_rew_mean          | -1.25e+03   |
# | time/                   |             |
# |    fps                  | 300         |
# |    iterations           | 18          |
# |    time_elapsed         | 122         |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.017856812 |
# |    clip_fraction        | 0.109       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | 0.000242    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 170         |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0127     |
# |    value_loss           | 474         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.6e+03     |
# |    ep_rew_mean          | -1.23e+03   |
# | time/                   |             |
# |    fps                  | 300         |
# |    iterations           | 19          |
# |    time_elapsed         | 129         |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.011498173 |
# |    clip_fraction        | 0.094       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | -2.54e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 185         |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.000979   |
# |    value_loss           | 327         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.6e+03     |
# |    ep_rew_mean          | -1.26e+03   |
# | time/                   |             |
# |    fps                  | 300         |
# |    iterations           | 20          |
# |    time_elapsed         | 136         |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.011636633 |
# |    clip_fraction        | 0.0958      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | -1.31e-06   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 60.4        |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0105     |
# |    value_loss           | 184         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.6e+03     |
# |    ep_rew_mean          | -1.25e+03   |
# | time/                   |             |
# |    fps                  | 300         |
# |    iterations           | 21          |
# |    time_elapsed         | 143         |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.012974234 |
# |    clip_fraction        | 0.103       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | 1.25e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 167         |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0108     |
# |    value_loss           | 530         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.6e+03     |
# |    ep_rew_mean          | -1.26e+03   |
# | time/                   |             |
# |    fps                  | 300         |
# |    iterations           | 22          |
# |    time_elapsed         | 149         |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.019152142 |
# |    clip_fraction        | 0.0993      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | 2.09e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 48.5        |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0108     |
# |    value_loss           | 189         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.6e+03    |
# |    ep_rew_mean          | -1.26e+03  |
# | time/                   |            |
# |    fps                  | 300        |
# |    iterations           | 23         |
# |    time_elapsed         | 156        |
# |    total_timesteps      | 47104      |
# | train/                  |            |
# |    approx_kl            | 0.01187592 |
# |    clip_fraction        | 0.0717     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.37      |
# |    explained_variance   | -0.000279  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 168        |
# |    n_updates            | 220        |
# |    policy_gradient_loss | -0.00645   |
# |    value_loss           | 509        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.6e+03     |
# |    ep_rew_mean          | -1.27e+03   |
# | time/                   |             |
# |    fps                  | 300         |
# |    iterations           | 24          |
# |    time_elapsed         | 163         |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.009942677 |
# |    clip_fraction        | 0.126       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | -2.38e-06   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 82.3        |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.0137     |
# |    value_loss           | 295         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.6e+03     |
# |    ep_rew_mean          | -1.24e+03   |
# | time/                   |             |
# |    fps                  | 300         |
# |    iterations           | 25          |
# |    time_elapsed         | 170         |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.011087681 |
# |    clip_fraction        | 0.173       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 126         |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0152     |
# |    value_loss           | 399         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.6e+03      |
# |    ep_rew_mean          | -1.24e+03    |
# | time/                   |              |
# |    fps                  | 300          |
# |    iterations           | 26           |
# |    time_elapsed         | 177          |
# |    total_timesteps      | 53248        |
# | train/                  |              |
# |    approx_kl            | 0.0045821685 |
# |    clip_fraction        | 0.0548       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | 4.05e-06     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 42.4         |
# |    n_updates            | 250          |
# |    policy_gradient_loss | -0.0031      |
# |    value_loss           | 233          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.6e+03      |
# |    ep_rew_mean          | -1.24e+03    |
# | time/                   |              |
# |    fps                  | 300          |
# |    iterations           | 27           |
# |    time_elapsed         | 184          |
# |    total_timesteps      | 55296        |
# | train/                  |              |
# |    approx_kl            | 0.0070890174 |
# |    clip_fraction        | 0.0602       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | 0.000839     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 36.6         |
# |    n_updates            | 260          |
# |    policy_gradient_loss | -0.00573     |
# |    value_loss           | 284          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.6e+03     |
# |    ep_rew_mean          | -1.25e+03   |
# | time/                   |             |
# |    fps                  | 300         |
# |    iterations           | 28          |
# |    time_elapsed         | 190         |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.017125368 |
# |    clip_fraction        | 0.184       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | 0.0393      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 168         |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.0147     |
# |    value_loss           | 461         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.6e+03     |
# |    ep_rew_mean          | -1.24e+03   |
# | time/                   |             |
# |    fps                  | 299         |
# |    iterations           | 29          |
# |    time_elapsed         | 198         |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.016675748 |
# |    clip_fraction        | 0.103       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | 1.28e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 116         |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.000987   |
# |    value_loss           | 317         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.6e+03     |
# |    ep_rew_mean          | -1.23e+03   |
# | time/                   |             |
# |    fps                  | 298         |
# |    iterations           | 30          |
# |    time_elapsed         | 205         |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.010778958 |
# |    clip_fraction        | 0.126       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | 0.0106      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 77.5        |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.00933    |
# |    value_loss           | 362         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.6e+03      |
# |    ep_rew_mean          | -1.24e+03    |
# | time/                   |              |
# |    fps                  | 298          |
# |    iterations           | 31           |
# |    time_elapsed         | 212          |
# |    total_timesteps      | 63488        |
# | train/                  |              |
# |    approx_kl            | 0.0039156154 |
# |    clip_fraction        | 0.14         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | 5.98e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 286          |
# |    n_updates            | 300          |
# |    policy_gradient_loss | -0.00157     |
# |    value_loss           | 222          |
# ------------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1.6e+03   |
# |    ep_rew_mean          | -1.25e+03 |
# | time/                   |           |
# |    fps                  | 298       |
# |    iterations           | 32        |
# |    time_elapsed         | 219       |
# |    total_timesteps      | 65536     |
# | train/                  |           |
# |    approx_kl            | 0.0156871 |
# |    clip_fraction        | 0.177     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.38     |
# |    explained_variance   | 0.0376    |
# |    learning_rate        | 0.0003    |
# |    loss                 | 186       |
# |    n_updates            | 310       |
# |    policy_gradient_loss | -0.0136   |
# |    value_loss           | 584       |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.6e+03     |
# |    ep_rew_mean          | -1.23e+03   |
# | time/                   |             |
# |    fps                  | 298         |
# |    iterations           | 33          |
# |    time_elapsed         | 226         |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.009205615 |
# |    clip_fraction        | 0.122       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | -0.00394    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 71          |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.00771    |
# |    value_loss           | 295         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.6e+03     |
# |    ep_rew_mean          | -1.23e+03   |
# | time/                   |             |
# |    fps                  | 297         |
# |    iterations           | 34          |
# |    time_elapsed         | 233         |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.009280736 |
# |    clip_fraction        | 0.0626      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | 0.049       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 52          |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.00572    |
# |    value_loss           | 288         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.6e+03     |
# |    ep_rew_mean          | -1.23e+03   |
# | time/                   |             |
# |    fps                  | 297         |
# |    iterations           | 35          |
# |    time_elapsed         | 240         |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.011120094 |
# |    clip_fraction        | 0.128       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | 0.0484      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 101         |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.014      |
# |    value_loss           | 361         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.6e+03      |
# |    ep_rew_mean          | -1.22e+03    |
# | time/                   |              |
# |    fps                  | 297          |
# |    iterations           | 36           |
# |    time_elapsed         | 247          |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 0.0067850444 |
# |    clip_fraction        | 0.0636       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | 0.187        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 49.4         |
# |    n_updates            | 350          |
# |    policy_gradient_loss | -0.00543     |
# |    value_loss           | 192          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.6e+03     |
# |    ep_rew_mean          | -1.22e+03   |
# | time/                   |             |
# |    fps                  | 298         |
# |    iterations           | 37          |
# |    time_elapsed         | 254         |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.016056195 |
# |    clip_fraction        | 0.172       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | 0.00557     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 274         |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.0127     |
# |    value_loss           | 439         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.6e+03     |
# |    ep_rew_mean          | -1.22e+03   |
# | time/                   |             |
# |    fps                  | 298         |
# |    iterations           | 38          |
# |    time_elapsed         | 260         |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.013192987 |
# |    clip_fraction        | 0.15        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | 0.169       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 52.1        |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.00785    |
# |    value_loss           | 258         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.6e+03     |
# |    ep_rew_mean          | -1.22e+03   |
# | time/                   |             |
# |    fps                  | 299         |
# |    iterations           | 39          |
# |    time_elapsed         | 266         |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.011249186 |
# |    clip_fraction        | 0.0902      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | 0.372       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 52.2        |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.0061     |
# |    value_loss           | 305         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.6e+03     |
# |    ep_rew_mean          | -1.22e+03   |
# | time/                   |             |
# |    fps                  | 299         |
# |    iterations           | 40          |
# |    time_elapsed         | 273         |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.006630135 |
# |    clip_fraction        | 0.0618      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | 0.0804      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 26.2        |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.00771    |
# |    value_loss           | 136         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.6e+03     |
# |    ep_rew_mean          | -1.22e+03   |
# | time/                   |             |
# |    fps                  | 299         |
# |    iterations           | 41          |
# |    time_elapsed         | 280         |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.013817988 |
# |    clip_fraction        | 0.146       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | 0.711       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 176         |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.00739    |
# |    value_loss           | 221         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.6e+03      |
# |    ep_rew_mean          | -1.21e+03    |
# | time/                   |              |
# |    fps                  | 299          |
# |    iterations           | 42           |
# |    time_elapsed         | 286          |
# |    total_timesteps      | 86016        |
# | train/                  |              |
# |    approx_kl            | 0.0075294143 |
# |    clip_fraction        | 0.0679       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | 0.111        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 85.5         |
# |    n_updates            | 410          |
# |    policy_gradient_loss | -0.00663     |
# |    value_loss           | 179          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.6e+03     |
# |    ep_rew_mean          | -1.23e+03   |
# | time/                   |             |
# |    fps                  | 300         |
# |    iterations           | 43          |
# |    time_elapsed         | 293         |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.009614147 |
# |    clip_fraction        | 0.0701      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | -0.06       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 58.9        |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.00898    |
# |    value_loss           | 148         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.6e+03     |
# |    ep_rew_mean          | -1.22e+03   |
# | time/                   |             |
# |    fps                  | 300         |
# |    iterations           | 44          |
# |    time_elapsed         | 300         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.012093198 |
# |    clip_fraction        | 0.11        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | 0.218       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 68.1        |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.0118     |
# |    value_loss           | 333         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.6e+03     |
# |    ep_rew_mean          | -1.22e+03   |
# | time/                   |             |
# |    fps                  | 299         |
# |    iterations           | 45          |
# |    time_elapsed         | 307         |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.007726189 |
# |    clip_fraction        | 0.0589      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | -0.0133     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 131         |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.00887    |
# |    value_loss           | 246         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.6e+03     |
# |    ep_rew_mean          | -1.22e+03   |
# | time/                   |             |
# |    fps                  | 300         |
# |    iterations           | 46          |
# |    time_elapsed         | 313         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.014576338 |
# |    clip_fraction        | 0.169       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | 0.111       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 63.7        |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.0125     |
# |    value_loss           | 137         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.6e+03     |
# |    ep_rew_mean          | -1.21e+03   |
# | time/                   |             |
# |    fps                  | 300         |
# |    iterations           | 47          |
# |    time_elapsed         | 320         |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.004258536 |
# |    clip_fraction        | 0.016       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | 0.243       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 149         |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.00304    |
# |    value_loss           | 198         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.6e+03     |
# |    ep_rew_mean          | -1.21e+03   |
# | time/                   |             |
# |    fps                  | 300         |
# |    iterations           | 48          |
# |    time_elapsed         | 327         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.010714253 |
# |    clip_fraction        | 0.159       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | -0.0889     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 80.9        |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.00922    |
# |    value_loss           | 275         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.6e+03     |
# |    ep_rew_mean          | -1.22e+03   |
# | time/                   |             |
# |    fps                  | 299         |
# |    iterations           | 49          |
# |    time_elapsed         | 334         |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.007306641 |
# |    clip_fraction        | 0.0851      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | 0.384       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 38.1        |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.0119     |
# |    value_loss           | 184         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.6e+03     |
# |    ep_rew_mean          | -1.22e+03   |
# | time/                   |             |
# |    fps                  | 300         |
# |    iterations           | 50          |
# |    time_elapsed         | 341         |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.010003129 |
# |    clip_fraction        | 0.127       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | 0.415       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 387         |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.00916    |
# |    value_loss           | 339         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.6e+03     |
# |    ep_rew_mean          | -1.21e+03   |
# | time/                   |             |
# |    fps                  | 300         |
# |    iterations           | 51          |
# |    time_elapsed         | 347         |
# |    total_timesteps      | 104448      |
# | train/                  |             |
# |    approx_kl            | 0.011363199 |
# |    clip_fraction        | 0.0884      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | 0.358       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 273         |
# |    n_updates            | 500         |
# |    policy_gradient_loss | -0.00695    |
# |    value_loss           | 269         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.6e+03     |
# |    ep_rew_mean          | -1.2e+03    |
# | time/                   |             |
# |    fps                  | 300         |
# |    iterations           | 52          |
# |    time_elapsed         | 354         |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.008630732 |
# |    clip_fraction        | 0.0803      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | 0.635       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 15.5        |
# |    n_updates            | 510         |
# |    policy_gradient_loss | -0.00656    |
# |    value_loss           | 142         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.6e+03     |
# |    ep_rew_mean          | -1.21e+03   |
# | time/                   |             |
# |    fps                  | 300         |
# |    iterations           | 53          |
# |    time_elapsed         | 361         |
# |    total_timesteps      | 108544      |
# | train/                  |             |
# |    approx_kl            | 0.010699533 |
# |    clip_fraction        | 0.12        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | 0.303       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 25.7        |
# |    n_updates            | 520         |
# |    policy_gradient_loss | -0.0119     |
# |    value_loss           | 114         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.6e+03     |
# |    ep_rew_mean          | -1.2e+03    |
# | time/                   |             |
# |    fps                  | 300         |
# |    iterations           | 54          |
# |    time_elapsed         | 367         |
# |    total_timesteps      | 110592      |
# | train/                  |             |
# |    approx_kl            | 0.009253334 |
# |    clip_fraction        | 0.119       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | 0.752       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 24.2        |
# |    n_updates            | 530         |
# |    policy_gradient_loss | -0.00993    |
# |    value_loss           | 194         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.6e+03     |
# |    ep_rew_mean          | -1.19e+03   |
# | time/                   |             |
# |    fps                  | 300         |
# |    iterations           | 55          |
# |    time_elapsed         | 374         |
# |    total_timesteps      | 112640      |
# | train/                  |             |
# |    approx_kl            | 0.011584079 |
# |    clip_fraction        | 0.131       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | 0.647       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 80.3        |
# |    n_updates            | 540         |
# |    policy_gradient_loss | -0.00504    |
# |    value_loss           | 268         |
# ...
# |    n_updates            | 1770       |
# |    policy_gradient_loss | -0.00774   |
# |    value_loss           | 158        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.6e+03     |
# |    ep_rew_mean          | -1.24e+03   |
# | time/                   |             |
# |    fps                  | 298         |
# |    iterations           | 179         |
# |    time_elapsed         | 1228        |
# |    total_timesteps      | 366592      |
# | train/                  |             |
# |    approx_kl            | 0.011940664 |
# |    clip_fraction        | 0.136       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.32       |
# |    explained_variance   | 0.547       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 43.4        |
# |    n_updates            | 1780        |
# |    policy_gradient_loss | -0.00947    |
# |    value_loss           | 121         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.6e+03     |
# |    ep_rew_mean          | -1.24e+03   |
# | time/                   |             |
# |    fps                  | 298         |
# |    iterations           | 180         |
# |    time_elapsed         | 1236        |
# |    total_timesteps      | 368640      |
# | train/                  |             |
# |    approx_kl            | 0.016795535 |
# |    clip_fraction        | 0.176       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.31       |
# |    explained_variance   | 0.43        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 62.9        |
# |    n_updates            | 1790        |
# |    policy_gradient_loss | -0.00652    |
# |    value_loss           | 218         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.6e+03    |
# |    ep_rew_mean          | -1.24e+03  |
# | time/                   |            |
# |    fps                  | 298        |
# |    iterations           | 181        |
# |    time_elapsed         | 1243       |
# |    total_timesteps      | 370688     |
# | train/                  |            |
# |    approx_kl            | 0.00905337 |
# |    clip_fraction        | 0.159      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.32      |
# |    explained_variance   | 0.755      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 176        |
# |    n_updates            | 1800       |
# |    policy_gradient_loss | -0.0058    |
# |    value_loss           | 238        |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.6e+03      |
# |    ep_rew_mean          | -1.24e+03    |
# | time/                   |              |
# |    fps                  | 298          |
# |    iterations           | 182          |
# |    time_elapsed         | 1249         |
# |    total_timesteps      | 372736       |
# | train/                  |              |
# |    approx_kl            | 0.0125853885 |
# |    clip_fraction        | 0.164        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.33        |
# |    explained_variance   | 0.136        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 42.1         |
# |    n_updates            | 1810         |
# |    policy_gradient_loss | -0.00862     |
# |    value_loss           | 135          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.6e+03     |
# |    ep_rew_mean          | -1.23e+03   |
# | time/                   |             |
# |    fps                  | 298         |
# |    iterations           | 183         |
# |    time_elapsed         | 1256        |
# |    total_timesteps      | 374784      |
# | train/                  |             |
# |    approx_kl            | 0.014571076 |
# |    clip_fraction        | 0.174       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.31       |
# |    explained_variance   | 0.442       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 62.2        |
# |    n_updates            | 1820        |
# |    policy_gradient_loss | -0.0116     |
# |    value_loss           | 165         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.6e+03     |
# |    ep_rew_mean          | -1.24e+03   |
# | time/                   |             |
# |    fps                  | 298         |
# |    iterations           | 184         |
# |    time_elapsed         | 1263        |
# |    total_timesteps      | 376832      |
# | train/                  |             |
# |    approx_kl            | 0.011753172 |
# |    clip_fraction        | 0.11        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.31       |
# |    explained_variance   | 0.631       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 36.4        |
# |    n_updates            | 1830        |
# |    policy_gradient_loss | -0.00692    |
# |    value_loss           | 129         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.6e+03      |
# |    ep_rew_mean          | -1.23e+03    |
# | time/                   |              |
# |    fps                  | 298          |
# |    iterations           | 185          |
# |    time_elapsed         | 1270         |
# |    total_timesteps      | 378880       |
# | train/                  |              |
# |    approx_kl            | 0.0121310055 |
# |    clip_fraction        | 0.149        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.32        |
# |    explained_variance   | 0.627        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 36.7         |
# |    n_updates            | 1840         |
# |    policy_gradient_loss | -0.00594     |
# |    value_loss           | 162          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.6e+03     |
# |    ep_rew_mean          | -1.21e+03   |
# | time/                   |             |
# |    fps                  | 298         |
# |    iterations           | 186         |
# |    time_elapsed         | 1277        |
# |    total_timesteps      | 380928      |
# | train/                  |             |
# |    approx_kl            | 0.009605255 |
# |    clip_fraction        | 0.118       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.32       |
# |    explained_variance   | 0.918       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 24.1        |
# |    n_updates            | 1850        |
# |    policy_gradient_loss | -0.00661    |
# |    value_loss           | 118         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.6e+03     |
# |    ep_rew_mean          | -1.2e+03    |
# | time/                   |             |
# |    fps                  | 298         |
# |    iterations           | 187         |
# |    time_elapsed         | 1284        |
# |    total_timesteps      | 382976      |
# | train/                  |             |
# |    approx_kl            | 0.011744564 |
# |    clip_fraction        | 0.127       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | 0.88        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 40.3        |
# |    n_updates            | 1860        |
# |    policy_gradient_loss | -0.00912    |
# |    value_loss           | 213         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.6e+03     |
# |    ep_rew_mean          | -1.21e+03   |
# | time/                   |             |
# |    fps                  | 298         |
# |    iterations           | 188         |
# |    time_elapsed         | 1290        |
# |    total_timesteps      | 385024      |
# | train/                  |             |
# |    approx_kl            | 0.008288772 |
# |    clip_fraction        | 0.115       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | 0.785       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 39.2        |
# |    n_updates            | 1870        |
# |    policy_gradient_loss | -0.00885    |
# |    value_loss           | 76.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.6e+03     |
# |    ep_rew_mean          | -1.21e+03   |
# | time/                   |             |
# |    fps                  | 298         |
# |    iterations           | 189         |
# |    time_elapsed         | 1297        |
# |    total_timesteps      | 387072      |
# | train/                  |             |
# |    approx_kl            | 0.019024383 |
# |    clip_fraction        | 0.308       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | 0.541       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 43.8        |
# |    n_updates            | 1880        |
# |    policy_gradient_loss | -0.0233     |
# |    value_loss           | 131         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.6e+03     |
# |    ep_rew_mean          | -1.2e+03    |
# | time/                   |             |
# |    fps                  | 298         |
# |    iterations           | 190         |
# |    time_elapsed         | 1305        |
# |    total_timesteps      | 389120      |
# | train/                  |             |
# |    approx_kl            | 0.012280615 |
# |    clip_fraction        | 0.172       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.31       |
# |    explained_variance   | 0.77        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 26.9        |
# |    n_updates            | 1890        |
# |    policy_gradient_loss | -0.00811    |
# |    value_loss           | 83.1        |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1.6e+03   |
# |    ep_rew_mean          | -1.2e+03  |
# | time/                   |           |
# |    fps                  | 297       |
# |    iterations           | 191       |
# |    time_elapsed         | 1313      |
# |    total_timesteps      | 391168    |
# | train/                  |           |
# |    approx_kl            | 0.0119301 |
# |    clip_fraction        | 0.179     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.31     |
# |    explained_variance   | 0.917     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 52.7      |
# |    n_updates            | 1900      |
# |    policy_gradient_loss | -0.0108   |
# |    value_loss           | 141       |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.6e+03     |
# |    ep_rew_mean          | -1.19e+03   |
# | time/                   |             |
# |    fps                  | 297         |
# |    iterations           | 192         |
# |    time_elapsed         | 1321        |
# |    total_timesteps      | 393216      |
# | train/                  |             |
# |    approx_kl            | 0.013978578 |
# |    clip_fraction        | 0.147       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.28       |
# |    explained_variance   | 0.747       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 21.8        |
# |    n_updates            | 1910        |
# |    policy_gradient_loss | -0.0101     |
# |    value_loss           | 85          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.6e+03     |
# |    ep_rew_mean          | -1.19e+03   |
# | time/                   |             |
# |    fps                  | 297         |
# |    iterations           | 193         |
# |    time_elapsed         | 1330        |
# |    total_timesteps      | 395264      |
# | train/                  |             |
# |    approx_kl            | 0.011732625 |
# |    clip_fraction        | 0.168       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.31       |
# |    explained_variance   | 0.784       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 15.7        |
# |    n_updates            | 1920        |
# |    policy_gradient_loss | -0.00504    |
# |    value_loss           | 57          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.6e+03     |
# |    ep_rew_mean          | -1.19e+03   |
# | time/                   |             |
# |    fps                  | 296         |
# |    iterations           | 194         |
# |    time_elapsed         | 1337        |
# |    total_timesteps      | 397312      |
# | train/                  |             |
# |    approx_kl            | 0.015049484 |
# |    clip_fraction        | 0.171       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.29       |
# |    explained_variance   | -0.0124     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 35.1        |
# |    n_updates            | 1930        |
# |    policy_gradient_loss | -0.0111     |
# |    value_loss           | 73.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.6e+03     |
# |    ep_rew_mean          | -1.2e+03    |
# | time/                   |             |
# |    fps                  | 296         |
# |    iterations           | 195         |
# |    time_elapsed         | 1345        |
# |    total_timesteps      | 399360      |
# | train/                  |             |
# |    approx_kl            | 0.013304373 |
# |    clip_fraction        | 0.185       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.28       |
# |    explained_variance   | 0.808       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 23.5        |
# |    n_updates            | 1940        |
# |    policy_gradient_loss | -0.00627    |
# |    value_loss           | 85          |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.6e+03    |
# |    ep_rew_mean          | -1.22e+03  |
# | time/                   |            |
# |    fps                  | 296        |
# |    iterations           | 196        |
# |    time_elapsed         | 1353       |
# |    total_timesteps      | 401408     |
# | train/                  |            |
# |    approx_kl            | 0.01887127 |
# |    clip_fraction        | 0.296      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.3       |
# |    explained_variance   | -0.42      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 44         |
# |    n_updates            | 1950       |
# |    policy_gradient_loss | -0.0107    |
# |    value_loss           | 196        |
# ----------------------------------------

# %%
average = 0
length = 0
for i in range(5):
    obs, _ = env.reset()
    while True:
        # Next action:
        # (feed the observation to your agent here)
        action = model.predict(obs)

        # Processing:
        obs, reward, terminated, _, info = env.step(action[0])
        average += reward
        length += 1
        # Rendering the game:
        # (remove this two lines during training)
        env.render()
        time.sleep(1 / 600)  # FPS
        
        # Checking if the player is still alive
        if terminated:
            break

    env.close()
print(length/5)
print(average/5)
# Out:
# 1600.0
# -1330.0

# %%
pygame.quit()
